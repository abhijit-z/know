# %% [markdown]
# # Movies Database

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
mfile = "C:/Users/hp/Downloads/Python Resources and learning Manoj Sir/IMDb movies.csv/IMDb movies.csv"

# %%
df_movies = pd.read_csv(mfile, parse_dates =['date_published', 'year'])

# %%
df_movies['year'] = df_movies['year'].dt.year

# %%
df_movies.tail()
# Out:
#       imdb_title_id                      title             original_title  \
# 81268     tt9903716                     Jessie                     Jessie
# 81269     tt9905412                      Ottam                      Ottam
# 81270     tt9905462                  Pengalila                  Pengalila
# 81271     tt9911774  Padmavyuhathile Abhimanyu  Padmavyuhathile Abhimanyu
# 81272     tt9914286          Sokagin Çocuklari          Sokagin Çocuklari
#
#        year date_published             genre  duration country   language  \
# 81268  2019     2019-03-15  Horror, Thriller       106   India     Telugu
# 81269  2019     2019-03-08             Drama       120   India  Malayalam
# 81270  2019     2019-03-08             Drama       111   India  Malayalam
# 81271  2019     2019-03-08             Drama       130   India  Malayalam
# 81272  2019     2019-03-15     Drama, Family        98  Turkey    Turkish
#
#                 director  ...  \
# 81268    Aswani Kumar V.  ...
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  datetime64[ns]
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
# ...

# %%
df_IND = df_movies[df_movies['country'] == 'India']

# %%
df_US = df_movies[df_movies['country'] == 'USA']

# %%
df_FR = df_movies[df_movies['country'] == 'France']

# %%
plt.figure()
b = plt.boxplot([df_IND['duration'], df_US['duration'], df_FR['duration']],  labels = ('India','USA','France'))
plt.ylabel('Movie Duration in minutes')
plt.xlabel('Countries')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Countries')

# %%
df_IND.mean()
# Out:
# year                    2004.415162
# duration                 140.425812
# avg_vote                   6.257166
# votes                   2439.500000
# metascore                 55.882353
# reviews_from_users        20.662218
# reviews_from_critics       6.883784
# dtype: float64

# %%
temp = df_IND[df_IND['avg_vote']==7.4]

# %%
temp.head()
# Out:
#      imdb_title_id              title     original_title  year date_published  \
# 5802     tt0041123              Andaz              Andaz  1949     1949-01-01
# 6450     tt0043307              Baazi              Baazi  1951     1951-01-01
# 6801     tt0044392        Baiju Bawra        Baiju Bawra  1952     1952-01-01
# 8254     tt0049041             C.I.D.             C.I.D.  1956     1956-04-06
# 9012     tt0051399  Bari Theke Paliye  Bari Theke Paliye  1958     1958-06-24
#
#                         genre  duration country language       director  ...  \
# 5802    Musical, Drama, Crime       148   India    Hindi   Mehboob Khan  ...
# 6450    Crime, Drama, Musical       143   India    Hindi      Guru Dutt  ...
# 6801  Drama, Musical, Romance       165   India    Hindi    Vijay Bhatt  ...
# 8254   Action, Crime, Musical       146   India    Hindi     Raj Khosla  ...
# 9012                    Drama       124   India  Bengali  Ritwik Ghatak  ...
#
# ...

# %%
plt.figure(figsize =(15,5))
ax1 = plt.subplot(1, 2 ,1).hist(df_IND['avg_vote'], bins = 20)
plt.xticks(np.arange(df_IND['avg_vote'].min(), df_IND['avg_vote'].max() + 1, 0.5 ));
#ax2 = plt.subplot(1, 2, 2).hist(df_US['avg_vote'], bins = 20)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
plt.figure(figsize =(8,4))
ax1 = plt.subplot(1, 2 ,1)
ax1.hist(df_IND['avg_vote'], edgecolor='black', bins = 20) # Gaussian Histogram
ax1.set_xticks(np.arange(df_IND['avg_vote'].min(), df_IND['avg_vote'].max() + 1, 1 ));
# set_xticks is used to customise the ticks. We can use it to customise individual subplots.
# whereas xticks works with prefix of matplot.pyplot

ax1.set_xlabel('Average vote/rating')
ax1.set_ylabel('Number of movies')

ax2 = plt.subplot(1, 2, 2)
ax2.hist(df_US['avg_vote'], bins = 20)
ax2.set_xticks(np.arange(0, df_US['avg_vote'].max() + 1, 1 ));

ax2.set_xlabel('Average vote/rating')
# ax2.set_ylabel('Number of movies')


#plt.subplot(1, 2, 2).xticks(np.arange(df_US['avg_vote'].min(), df_US['avg_vote'].max() + 1, 1 ));
# plt.sca(ax2)
# plt.subplots_adjust(bottom = 0.25)
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5, 0, 'Average vote/rating')

# %%
## For loop for ticks : will be helpful if there are many subplots
# import matplotlib.pyplot as plt
# f, axs = plt.subplots(ncols=2)
# for i in range(2):
#    ax = axs[i]
#    ax.set_xticks(range(6))
#    ax.set_xticklabels([str(x)+"foo" for x in range(6)], rotation=45)
#    ax.plot(range(6), range(6))
# plt.show()

# %%
type(ax2)
# Out:
# tuple

# %%
df_movies.groupby('language').count().sort_values('title',ascending = False)
# Out:
#                                                     imdb_title_id  title  \
# language
# English                                                     34519  34519
# French                                                       3777   3777
# Spanish                                                      2640   2640
# Japanese                                                     2605   2605
# Italian                                                      2565   2565
# ...                                                           ...    ...
# English, Spanish, Japanese, Hebrew, Persian, Po...              1      1
# English, Spanish, Japanese, Hindi                               1      1
# English, Spanish, Japanese, Russian, Chinese                    1      1
# English, Spanish, Latin, French                                 1      1
# Zulu, Xhosa, Afrikaans, English                                 1      1
#
#                                                     original_title   year  \
# ...

# %%
df_lang = df_movies[(df_movies['language'] == 'Hindi') | (df_movies['language'] == 'English') | (df_movies['language'] == 'Spanish') | (df_movies['language'] == 'French')]

# %%
df_lang[['language', 'duration', 'avg_vote']].head()
# Out:
#    language  duration  avg_vote
# 2   English       100       5.2
# 4   English        60       5.7
# 8   English        55       5.5
# 10   French        54       7.0
# 12   French        61       7.0

# %%
df_pairplot = df_lang[['language', 'duration', 'avg_vote']]

# %%
sns.pairplot(df_pairplot, hue='language', diag_kind='kde', height=3);
# Out:
# <img src="data:image/png;base64,..." width="704">

# %%
df_hin = df_movies[df_movies['language'] == 'Hindi']
df_eng = df_movies[df_movies['language'] == 'English']
df_esp = df_movies[df_movies['language'] == 'Spanish']
df_fre = df_movies[df_movies['language'] == 'French']

# %%
df_movies[df_movies['language'] == 'Hindi']
# Out:
#       imdb_title_id                            title  \
# 5479      tt0040067                              Aag
# 5802      tt0041123                            Andaz
# 5812      tt0041161                          Barsaat
# 6449      tt0043306                           Awaara
# 6450      tt0043307                            Baazi
# ...             ...                              ...
# 81081     tt9390222  72 Hours: Martyr Who Never Died
# 81096     tt9420648                             Bala
# 81124     tt9496212                         22 Yards
# 81203     tt9680166        Yeh Suhaagraat Impossible
# 81224     tt9766310                        Kanpuriye
#
#                         original_title  year date_published  \
# 5479                               Aag  1948     1948-08-06
# 5802                             Andaz  1949     1949-01-01
# 5812                           Barsaat  1949     1949-04-21
# 6449                            Awaara  1951     1951-12-14
# ...

# %%
df_movies[['country','duration','avg_vote']]
df_movies['language'].unique()[4000]
# Out:
# 'Swiss German, German, English, Italian'

# %%
df_movies.iloc[8000:8010, 17:22]
